# %%
import pandas as pd

df = pd.read_csv(r'registros_con_nulos.csv')

print(df.to_string())
# Out:
#       ID       Nombre  Edad    Ciudad              Correo
# 0      1    Persona_1  44.0  Ciudad_1    user1@correo.com
# 1      2    Persona_2  37.0  Ciudad_2    user2@correo.com
# 2      3    Persona_3  39.0  Ciudad_3    user3@correo.com
# 3      4    Persona_4  37.0  Ciudad_4                 NaN
# 4      5          NaN  26.0  Ciudad_5    user5@correo.com
# 5      6    Persona_6  20.0       NaN    user6@correo.com
# 6      7    Persona_7   NaN  Ciudad_7    user7@correo.com
# 7      8    Persona_8  53.0  Ciudad_8                 NaN
# 8      9    Persona_9  27.0  Ciudad_9    user9@correo.com
# 9     10          NaN  47.0  Ciudad_0   user10@correo.com
# 10    11   Persona_11  53.0  Ciudad_1   user11@correo.com
# 11    12   Persona_12  59.0       NaN                 NaN
# 12    13   Persona_13  47.0  Ciudad_3   user13@correo.com
# 13    14   Persona_14   NaN  Ciudad_4   user14@correo.com
# 14    15          NaN  21.0  Ciudad_5   user15@correo.com
# ...

# %%
print(df.isnull())
# Out:
#         ID  Nombre   Edad  Ciudad  Correo
# 0    False   False  False   False   False
# 1    False   False  False   False   False
# 2    False   False  False   False   False
# 3    False   False  False   False    True
# 4    False    True  False   False   False
# ..     ...     ...    ...     ...     ...
# 195  False   False   True   False    True
# 196  False   False  False   False   False
# 197  False   False  False    True   False
# 198  False   False  False   False   False
# 199  False    True  False   False    True
#
# [200 rows x 5 columns]

# %%
print(df.isnull().sum())
# Out:
# ID         0
# Nombre    40
# Edad      28
# Ciudad    33
# Correo    50
# dtype: int64

# %%
print(df.isna())
# Out:
#         ID  Nombre   Edad  Ciudad  Correo
# 0    False   False  False   False   False
# 1    False   False  False   False   False
# 2    False   False  False   False   False
# 3    False   False  False   False    True
# 4    False    True  False   False   False
# ..     ...     ...    ...     ...     ...
# 195  False   False   True   False    True
# 196  False   False  False   False   False
# 197  False   False  False    True   False
# 198  False   False  False   False   False
# 199  False    True  False   False    True
#
# [200 rows x 5 columns]

# %%
print(df.notnull())
# Out:
#        ID  Nombre   Edad  Ciudad  Correo
# 0    True    True   True    True    True
# 1    True    True   True    True    True
# 2    True    True   True    True    True
# 3    True    True   True    True   False
# 4    True   False   True    True    True
# ..    ...     ...    ...     ...     ...
# 195  True    True  False    True   False
# 196  True    True   True    True    True
# 197  True    True   True   False    True
# 198  True    True   True    True    True
# 199  True   False   True    True   False
#
# [200 rows x 5 columns]
